# %% [markdown]
# # ex2_scientific1
#
# ## Nội dung bài
# Hiển thị ngẫu nhiên $N=50$ hình tròn:
# + Tâm $c_i = (x_i, y_i)$ ngẫu nhiên với $x_i, y_i \in [0, 1]$
# + Màu sắc $color_i$ ngẫu nhiên với $color_i \in [0, 1]$
# + Diện tích $area_i = \pi * r_i^2$ với sinh ngẫu nhiên $r_i \in [0, 1]$
#
# ## Bài làm

# %% [markdown]
# ### Import thư viện

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython import display  # hiển thị rich output

# %% [markdown]
# ### Sinh ngẫu nhiên hình tròn

# %%
# %time
# generate randomly the center (x,y) of circle, color, area
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = np.pi * (15 * np.random.rand(N)) ** 2  # bán kính từ 0 tới 15
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns

# %%
# Mã kiểm tra dữ liệu
print(f'x: len={len(x):d}, [min={min(x):.2f}, [max={max(x):.2f}]]: 10 samples [{x[0:10]}]')
print(f'y: len={len(y):d}, [min={min(y):.2f}, [max={max(y):.2f}]]: 10 samples [{y[0:10]}]')
print(f'colors: len={len(colors):d}, [min={min(colors):.2f}, [max={max(colors):.2f}]]: 10 samples [{colors[0:10]}]')
print(f'area: len={len(area):d}, [min={min(area):.2f}, [max={max(area):.2f}]]: 10 samples [{area[0:10]}]')
# Out:
# x: len=50, [min=0.01, [max=1.00]]: 10 samples [[0.65096721 0.17880699 0.13798445 0.35056197 0.79378459 0.37236789
#  0.30616125 0.2534532  0.01139813 0.27877684]]
# y: len=50, [min=0.02, [max=0.99]]: 10 samples [[0.17330507 0.07539661 0.60694495 0.49868794 0.43961475 0.80300314
#  0.98593324 0.46450915 0.51015806 0.71901584]]
# colors: len=50, [min=0.01, [max=0.99]]: 10 samples [[0.69789495 0.46474887 0.65771902 0.32995492 0.28214448 0.15319949
#  0.423473   0.95856909 0.61745177 0.88614603]]
# area: len=50, [min=0.04, [max=607.88]]: 10 samples [[2.01616269e+02 9.72440942e+01 1.45142106e+02 5.15879066e+01
#  3.64361953e-02 3.71021994e+02 1.77683991e+02 3.69361262e+02
#  1.57649161e+02 1.57356361e+01]]

# %% [markdown]
# ### Hiển thị đồ thị

# %%
# %matplotlib inline
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %% [markdown]
# # Kết thúc
